# %% [markdown]
# # tbRec
#
# Notebook operacional para executar e inspecionar a extração de recolhimentos.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / 'pyproject.toml').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'tb_rec'))

import download_tb_rec as rec

rec.dry_run_plan()

# %%
# Descomente para executar a extração real.
# run = rec.run_tb_rec_export(verbose=True)
# run.summary
